# %%
import numpy as np
pi = np.atan(1)*4

# %%
a = np.abs(-42523.2)

# %%
print(f"{a}")
# Out:
# 42523.2

# %%
print(f"{a=}")
pi
# Out:
# a=np.float64(42523.2)
# np.float64(3.141592653589793)

# %% [markdown]
# ## Header
# the value of pi is `{python} f"{pi:.5g}"`
